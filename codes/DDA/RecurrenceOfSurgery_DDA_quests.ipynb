# %%
import pandas as pd
df_ROS = pd.read_csv('../../../datasets/RecurrenceOfSurgery.csv')
df_ROS[:2]
# Out:
#    Unnamed: 0.1  Unnamed: 0 환자ID  Large Lymphocyte  Location of herniation  \
# 0             0           0  1PT              22.8                       3
# 1             1           1  2PT              44.9                       4
#
#     ODI  가족력  간질성폐질환  고혈압여부  과거수술횟수  ...  Modic change    PI    PT  \
# 0  51.0  0.0       0      0       0  ...             3  51.6  36.6
# 1  26.0  0.0       0      0       0  ...             0  40.8   7.2
#
#    Seg Angle(raw)  Vaccum disc   골밀도  디스크단면적  디스크위치  척추이동척도  척추전방위증
# 0            14.4            0 -1.01  2048.5      4    Down       0
# 1            17.8            0 -1.14  1753.1      4      Up       0
#
# [2 rows x 53 columns]

# %%
df_ROS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0.1            1894 non-null   int64
#  1   Unnamed: 0              1894 non-null   int64
#  2   환자ID                    1894 non-null   object
#  3   Large Lymphocyte        1894 non-null   float64
#  4   Location of herniation  1894 non-null   int64
#  5   ODI                     462 non-null    float64
#  6   가족력                     1843 non-null   float64
#  7   간질성폐질환                  1894 non-null   int64
#  8   고혈압여부                   1894 non-null   int64
#  9   과거수술횟수                  1894 non-null   int64
#  10  당뇨여부                    1894 non-null   int64
#  11  말초동맥질환여부                1894 non-null   int64
#  12  빈혈여부                    1894 non-null   int64
#  13  성별                      1894 non-null   int64
# ...

# %%
df_ROS.isnull().sum()
# Out:
# Unnamed: 0.1                 0
# Unnamed: 0                   0
# 환자ID                         0
# Large Lymphocyte             0
# Location of herniation       0
# ODI                       1432
# 가족력                         51
# 간질성폐질환                       0
# 고혈압여부                        0
# 과거수술횟수                       0
# 당뇨여부                         0
# 말초동맥질환여부                     0
# 빈혈여부                         0
# 성별                           0
# 스테로이드치료                      0
# 신부전여부                        0
# 신장                           0
# 심혈관질환                        0
# 암발병여부                        0
# 연령                           0
# 우울증여부                        0
# 입원기간                         0
# 입원일자                         0
# 종양진행여부                       0
# 직업                         415
# 체중                           0
# 퇴원일자                         0
# 헤모글로빈수치                      1
# 혈전합병증여부                      0
# 환자통증정도                       0
# ...

# %%
df_ROS_dropna=df_ROS.dropna()
df_ROS_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162 entries, 0 to 1216
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0.1            162 non-null    int64
#  1   Unnamed: 0              162 non-null    int64
#  2   환자ID                    162 non-null    object
#  3   Large Lymphocyte        162 non-null    float64
#  4   Location of herniation  162 non-null    int64
#  5   ODI                     162 non-null    float64
#  6   가족력                     162 non-null    float64
#  7   간질성폐질환                  162 non-null    int64
#  8   고혈압여부                   162 non-null    int64
#  9   과거수술횟수                  162 non-null    int64
#  10  당뇨여부                    162 non-null    int64
#  11  말초동맥질환여부                162 non-null    int64
#  12  빈혈여부                    162 non-null    int64
#  13  성별                      162 non-null    int64
# ...

# %%
df_ROS.dropna(subset=['직업']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1479 entries, 0 to 1893
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0.1            1479 non-null   int64
#  1   Unnamed: 0              1479 non-null   int64
#  2   환자ID                    1479 non-null   object
#  3   Large Lymphocyte        1479 non-null   float64
#  4   Location of herniation  1479 non-null   int64
#  5   ODI                     344 non-null    float64
#  6   가족력                     1441 non-null   float64
#  7   간질성폐질환                  1479 non-null   int64
#  8   고혈압여부                   1479 non-null   int64
#  9   과거수술횟수                  1479 non-null   int64
#  10  당뇨여부                    1479 non-null   int64
#  11  말초동맥질환여부                1479 non-null   int64
#  12  빈혈여부                    1479 non-null   int64
#  13  성별                      1479 non-null   int64
# ...

# %%
df_ROS['신장'].describe()
# Out:
# count    1894.000000
# mean      168.027983
# std         9.211419
# min       140.000000
# 25%       161.000000
# 50%       169.000000
# 75%       175.000000
# max       204.000000
# Name: 신장, dtype: float64

# %%
Q1 = df_ROS['신장'].describe()['25%']
Q3 = df_ROS['신장'].describe()['75%']
