# %%
# %conda install pymongo

# %%
# import pymongo as mg
# import pandas as pd

# %%
# mg.__version__

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BNC_V2_1']

# %%
cursor = collection.find({})

# %%
list_BND = list(cursor)

# %%
list_BND
# Out:
# [{'_id': ObjectId('64d311e667fb952c17c9a166'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a167'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a168'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a169'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a16a'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a16b'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a16c'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a16d'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a16e'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a16f'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a170'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a171'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a172'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a173'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a174'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a175'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a176'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a177'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a178'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a179'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a17a'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a17b'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a17c'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a17d'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a17e'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a17f'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a180'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a181'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a182'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a183'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a184'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a185'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a186'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a187'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a188'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a189'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a18a'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a18b'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a18c'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a18d'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a18e'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a18f'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a190'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a191'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a192'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a193'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a194'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a195'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a196'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a197'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a198'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a199'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a19a'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a19b'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a19c'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a19d'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a19e'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a19f'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a0'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a1'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a2'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26410,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a3'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a4'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a5'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a6'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a7'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a8'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1a9'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1aa'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ab'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ac'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ad'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ae'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1af'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b0'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b1'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b2'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b3'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b4'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b5'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b6'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b7'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b8'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1b9'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ba'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1bb'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1bc'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1bd'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1be'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1bf'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c0'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c1'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c2'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c3'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c4'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c5'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c6'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c7'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c8'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1c9'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ca'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1cb'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1cc'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1cd'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ce'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1cf'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d0'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d1'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d2'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d3'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d4'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d5'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d6'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d7'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d8'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1d9'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1da'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1db'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1dc'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1dd'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1de'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1df'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e0'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e1'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e2'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e3'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e4'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e5'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e6'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e7'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e8'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1e9'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ea'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1eb'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ec'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ed'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ee'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ef'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f0'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f1'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f2'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f3'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f4'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f5'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f6'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f7'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f8'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1f9'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1fa'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1fb'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1fc'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1fd'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1fe'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a1ff'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a200'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a201'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a202'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a203'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a204'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a205'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a206'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a207'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a208'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a209'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a20a'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a20b'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a20c'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a20d'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a20e'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a20f'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a210'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a211'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a212'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a213'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a214'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a215'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a216'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a217'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a218'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a219'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a21a'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a21b'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a21c'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a21d'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a21e'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a21f'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a220'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a221'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a222'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a223'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a224'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a225'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a226'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a227'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a228'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a229'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a22a'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a22b'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a22c'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a22d'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a22e'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a22f'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a230'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a231'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a232'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a233'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a234'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a235'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a236'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a237'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a238'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a239'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a23a'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a23b'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a23c'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a23d'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a23e'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a23f'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a240'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a241'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a242'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a243'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a244'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a245'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a246'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a247'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a248'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a249'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a24a'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a24b'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a24c'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a24d'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a24e'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a24f'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a250'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a251'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a252'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a253'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a254'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a255'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a256'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a257'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a258'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a259'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a25a'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a25b'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a25c'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a25d'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a25e'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a25f'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a260'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a261'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a262'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a263'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a264'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a265'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a266'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a267'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a268'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a269'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a26a'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a26b'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a26c'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a26d'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a26e'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a26f'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a270'),
#   'STD_YYYY': 2006,
# ...
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4f6'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 82310,
#   'SEX': 2,
#   'SGG': 11740,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4f7'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4f8'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4f9'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4fa'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4fb'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4fc'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4fd'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4fe'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a4ff'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a500'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a501'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a502'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a503'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a504'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a505'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a506'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a507'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a508'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a509'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a50a'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a50b'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a50c'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a50d'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a50e'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a50f'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a510'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a511'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a512'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a513'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a514'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a515'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a516'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a517'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a518'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a519'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a51a'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a51b'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a51c'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a51d'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a51e'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a51f'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a520'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43112,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a521'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a522'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a523'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a524'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a525'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a526'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a527'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a528'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a529'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a52a'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a52b'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a52c'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a52d'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a52e'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a52f'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a530'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a531'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a532'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a533'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a534'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a535'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a536'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a537'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a538'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a539'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a53a'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a53b'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a53c'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a53d'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a53e'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a53f'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a540'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a541'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a542'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a543'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a544'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a545'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a546'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a547'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a548'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a549'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a54a'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a54b'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a54c'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311e667fb952c17c9a54d'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  ...]

# %%
df_BND = pd.DataFrame(list_BND)

# %%
df_BND
# Out:
#                             _id  STD_YYYY  RN_INDI  SEX    SGG  GAIBJA_TYPE  \
# 0      64d311e667fb952c17c9a166      2002     1433    1  29140            7
# 1      64d311e667fb952c17c9a167      2003     1433    1  29140            7
# 2      64d311e667fb952c17c9a168      2004     1433    1  29140            7
# 3      64d311e667fb952c17c9a169      2005     1433    1  29140            7
# 4      64d311e667fb952c17c9a16a      2006     1433    1  29140            7
# ...                         ...       ...      ...  ...    ...          ...
# 13022  64d311e667fb952c17c9d444      2012  3000357    2  28237            6
# 13023  64d311e667fb952c17c9d445      2013  3000357    2  28245            2
# 13024  64d311e667fb952c17c9d446      2014  3000357    2  28245            2
# 13025  64d311e667fb952c17c9d447      2015  3000357    2  28245            2
# 13026  64d311e667fb952c17c9d448      2015  3000758    1  41287            6
#
#        SMPL_TYPE_CD  CTRB_Q10 G1E_OBJ_YN  DSB_TYPE_CD  DSB_SVRT_CD_V2
# 0                 1       NaN        NaN          NaN             NaN
# 1                 1       NaN        NaN          NaN             NaN
# 2                 1       NaN        NaN          NaN             NaN
# 3                 1       NaN        NaN          NaN             NaN
# 4                 1       NaN        NaN          NaN             NaN
# ...             ...       ...        ...          ...             ...
# 13022             4       NaN        NaN          NaN             NaN
# 13023             4       6.0        NaN          NaN             NaN
# 13024             4       6.0        NaN          NaN             NaN
# 13025             4       7.0        NaN          NaN             NaN
# 13026             4       NaN        NaN          NaN             NaN
#
# [13027 rows x 11 columns]

# %%
df_BND.to_csv('./NSC2_BNC_V2_1.csv')
