# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BND']

# %%
cursor = collection.find({})

# %%
list_BND = list(cursor)

# %%
list_BND
# Out:
# [{'_id': ObjectId('64d2fd1a45d6ce1f3a35614f'),
#   'RN_INDI': 294364,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200707,
#   'COD1': 'T08-T14',
#   'COD2': 'W00-W19'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356150'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356151'),
#   'RN_INDI': 733575,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201309,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356152'),
#   'RN_INDI': 966199,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201409,
#   'COD1': 'J69'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356153'),
#   'RN_INDI': 972598,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C44'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356154'),
#   'RN_INDI': 979888,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201101,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356155'),
#   'RN_INDI': 991645,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201504,
#   'COD1': 'K92'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356156'),
#   'RN_INDI': 1002735,
#   'BTH_YYYY': 1922,
#   'DTH_YYYYMM': 200912,
#   'COD1': 'I63'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356157'),
#   'RN_INDI': 81830,
#   'BTH_YYYY': 1923,
#   'DTH_YYYYMM': 201106,
#   'COD1': 'K65'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356158'),
#   'RN_INDI': 126693,
#   'BTH_YYYY': 1924,
#   'DTH_YYYYMM': 201602,
#   'COD1': 'C23'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356159'),
#   'RN_INDI': 313232,
#   'BTH_YYYY': 1925,
#   'DTH_YYYYMM': 200802,
#   'COD1': 'I21'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35615a'),
#   'RN_INDI': 511135,
#   'BTH_YYYY': 1926,
#   'DTH_YYYYMM': 201808,
#   'COD1': 'A00-A09'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35615b'),
#   'RN_INDI': 734534,
#   'BTH_YYYY': 1926,
#   'DTH_YYYYMM': 201707,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35615c'),
#   'RN_INDI': 167044,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 200803,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35615d'),
#   'RN_INDI': 498406,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201012,
#   'COD1': 'F00-F09'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35615e'),
#   'RN_INDI': 847594,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201010,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35615f'),
#   'RN_INDI': 924012,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201903,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356160'),
#   'RN_INDI': 57736,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201602,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356161'),
#   'RN_INDI': 156212,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201502,
#   'COD1': 'I64'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356162'),
#   'RN_INDI': 647502,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201511,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356163'),
#   'RN_INDI': 776841,
#   'BTH_YYYY': 1929,
#   'DTH_YYYYMM': 201401,
#   'COD1': 'I20'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356164'),
#   'RN_INDI': 266922,
#   'BTH_YYYY': 1930},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356165'),
#   'RN_INDI': 278164,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201904,
#   'COD1': 'I63'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356166'),
#   'RN_INDI': 314204,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201109,
#   'COD1': 'I69'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356167'),
#   'RN_INDI': 394044,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201911,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356168'),
#   'RN_INDI': 415031,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201311,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356169'),
#   'RN_INDI': 563280,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35616a'),
#   'RN_INDI': 750849,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35616b'),
#   'RN_INDI': 933418,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35616c'),
#   'RN_INDI': 45815,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35616d'),
#   'RN_INDI': 60164,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201910,
#   'COD1': 'T51-T65',
#   'COD2': 'X00-X09'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35616e'),
#   'RN_INDI': 217071,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35616f'),
#   'RN_INDI': 661358,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356170'),
#   'RN_INDI': 780565,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356171'),
#   'RN_INDI': 830395,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201909,
#   'COD1': 'J80'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356172'),
#   'RN_INDI': 845220,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201610,
#   'COD1': 'E11'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356173'),
#   'RN_INDI': 904961,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201102,
#   'COD1': 'I50'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356174'),
#   'RN_INDI': 128764,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356175'),
#   'RN_INDI': 447304,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356176'),
#   'RN_INDI': 661690,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356177'),
#   'RN_INDI': 759704,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356178'),
#   'RN_INDI': 817724,
#   'BTH_YYYY': 1933,
#   'DTH_YYYYMM': 200907,
#   'COD1': 'I21'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356179'),
#   'RN_INDI': 891674,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35617a'),
#   'RN_INDI': 35364,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 201503,
#   'COD1': 'I25'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35617b'),
#   'RN_INDI': 374055,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35617c'),
#   'RN_INDI': 732273,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35617d'),
#   'RN_INDI': 823068,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 202105},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35617e'),
#   'RN_INDI': 830143,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35617f'),
#   'RN_INDI': 863928,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 200812,
#   'COD1': 'T08-T14',
#   'COD2': 'V20-V29'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356180'),
#   'RN_INDI': 929045,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 201008,
#   'COD1': 'J60'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356181'),
#   'RN_INDI': 6088,
#   'BTH_YYYY': 1935,
#   'DTH_YYYYMM': 201610,
#   'COD1': 'I46'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356182'),
#   'RN_INDI': 286730,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356183'),
#   'RN_INDI': 338024,
#   'BTH_YYYY': 1935,
#   'DTH_YYYYMM': 201904,
#   'COD1': 'C15'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356184'),
#   'RN_INDI': 356231,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356185'),
#   'RN_INDI': 940080,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356186'),
#   'RN_INDI': 451174,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201207,
#   'COD1': 'C90'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356187'),
#   'RN_INDI': 460880,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356188'),
#   'RN_INDI': 752341,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201905,
#   'COD1': 'B00-B09'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356189'),
#   'RN_INDI': 769362,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35618a'),
#   'RN_INDI': 892931,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35618b'),
#   'RN_INDI': 982512,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201009,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35618c'),
#   'RN_INDI': 986085,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201212,
#   'COD1': 'J44'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35618d'),
#   'RN_INDI': 121652,
#   'BTH_YYYY': 1937,
#   'DTH_YYYYMM': 202010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35618e'),
#   'RN_INDI': 211587,
#   'BTH_YYYY': 1937},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35618f'),
#   'RN_INDI': 639262,
#   'BTH_YYYY': 1937,
#   'DTH_YYYYMM': 201007,
#   'COD1': 'C16'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356190'),
#   'RN_INDI': 192153,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356191'),
#   'RN_INDI': 340919,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356192'),
#   'RN_INDI': 466622,
#   'BTH_YYYY': 1938,
#   'DTH_YYYYMM': 201409,
#   'COD1': 'T15-T19',
#   'COD2': 'W75-W84'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356193'),
#   'RN_INDI': 602767,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356194'),
#   'RN_INDI': 631088,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356195'),
#   'RN_INDI': 645281,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356196'),
#   'RN_INDI': 687590,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356197'),
#   'RN_INDI': 782784,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356198'),
#   'RN_INDI': 785193,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356199'),
#   'RN_INDI': 904381,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35619a'),
#   'RN_INDI': 136163,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35619b'),
#   'RN_INDI': 678141,
#   'BTH_YYYY': 1939,
#   'DTH_YYYYMM': 201210,
#   'COD1': 'T15-T19',
#   'COD2': 'W75-W84'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35619c'),
#   'RN_INDI': 734409,
#   'BTH_YYYY': 1939,
#   'DTH_YYYYMM': 201906,
#   'COD1': 'N18'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35619d'),
#   'RN_INDI': 752588,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35619e'),
#   'RN_INDI': 973001,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35619f'),
#   'RN_INDI': 202610,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a0'),
#   'RN_INDI': 588655,
#   'BTH_YYYY': 1940,
#   'DTH_YYYYMM': 201508,
#   'COD1': 'J81'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a1'),
#   'RN_INDI': 596321,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a2'),
#   'RN_INDI': 674283,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a3'),
#   'RN_INDI': 773366,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a4'),
#   'RN_INDI': 195032,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a5'),
#   'RN_INDI': 281502,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a6'),
#   'RN_INDI': 335999,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a7'),
#   'RN_INDI': 399667,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a8'),
#   'RN_INDI': 669847,
#   'BTH_YYYY': 1941,
#   'DTH_YYYYMM': 202011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561a9'),
#   'RN_INDI': 874400,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561aa'),
#   'RN_INDI': 19442,
#   'BTH_YYYY': 1942,
#   'DTH_YYYYMM': 202003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ab'),
#   'RN_INDI': 214085,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ac'),
#   'RN_INDI': 499129,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ad'),
#   'RN_INDI': 526484,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ae'),
#   'RN_INDI': 594404,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561af'),
#   'RN_INDI': 777023,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b0'),
#   'RN_INDI': 793097,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b1'),
#   'RN_INDI': 99170,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b2'),
#   'RN_INDI': 179035,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b3'),
#   'RN_INDI': 293594,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b4'),
#   'RN_INDI': 411541,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b5'),
#   'RN_INDI': 561959,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b6'),
#   'RN_INDI': 658248,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b7'),
#   'RN_INDI': 782489,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b8'),
#   'RN_INDI': 905179,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561b9'),
#   'RN_INDI': 138056,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ba'),
#   'RN_INDI': 423141,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561bb'),
#   'RN_INDI': 462208,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561bc'),
#   'RN_INDI': 641654,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561bd'),
#   'RN_INDI': 652355,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561be'),
#   'RN_INDI': 668008,
#   'BTH_YYYY': 1944,
#   'DTH_YYYYMM': 201909,
#   'COD1': 'I50'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561bf'),
#   'RN_INDI': 699543,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c0'),
#   'RN_INDI': 915167,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c1'),
#   'RN_INDI': 267631,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c2'),
#   'RN_INDI': 325107,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c3'),
#   'RN_INDI': 347480,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c4'),
#   'RN_INDI': 400685,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c5'),
#   'RN_INDI': 434429,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c6'),
#   'RN_INDI': 459027,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c7'),
#   'RN_INDI': 685794,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c8'),
#   'RN_INDI': 224374,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561c9'),
#   'RN_INDI': 516621,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ca'),
#   'RN_INDI': 635052,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561cb'),
#   'RN_INDI': 800215,
#   'BTH_YYYY': 1946,
#   'DTH_YYYYMM': 202103},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561cc'),
#   'RN_INDI': 838106,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561cd'),
#   'RN_INDI': 972420,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ce'),
#   'RN_INDI': 991935,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561cf'),
#   'RN_INDI': 49564,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 201509,
#   'COD1': 'C25'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d0'),
#   'RN_INDI': 73591,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 202105},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d1'),
#   'RN_INDI': 459355,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 200902,
#   'COD1': 'S00-S09',
#   'COD2': 'V01-V09'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d2'),
#   'RN_INDI': 557550,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 202008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d3'),
#   'RN_INDI': 618926,
#   'BTH_YYYY': 1947},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d4'),
#   'RN_INDI': 989524,
#   'BTH_YYYY': 1947},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d5'),
#   'RN_INDI': 43189,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d6'),
#   'RN_INDI': 335758,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d7'),
#   'RN_INDI': 352171,
#   'BTH_YYYY': 1948,
#   'DTH_YYYYMM': 202002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d8'),
#   'RN_INDI': 435393,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561d9'),
#   'RN_INDI': 557288,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561da'),
#   'RN_INDI': 646251,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561db'),
#   'RN_INDI': 794513,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561dc'),
#   'RN_INDI': 992976,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561dd'),
#   'RN_INDI': 6091,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561de'),
#   'RN_INDI': 174366,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561df'),
#   'RN_INDI': 291793,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e0'),
#   'RN_INDI': 293083,
#   'BTH_YYYY': 1949,
#   'DTH_YYYYMM': 200712,
#   'COD1': 'K70'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e1'),
#   'RN_INDI': 346560,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e2'),
#   'RN_INDI': 400705,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e3'),
#   'RN_INDI': 491396,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e4'),
#   'RN_INDI': 688356,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e5'),
#   'RN_INDI': 13486,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e6'),
#   'RN_INDI': 77520,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 201811,
#   'COD1': 'C25'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e7'),
#   'RN_INDI': 268861,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e8'),
#   'RN_INDI': 391223,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 202007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561e9'),
#   'RN_INDI': 418141,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ea'),
#   'RN_INDI': 577109,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561eb'),
#   'RN_INDI': 694471,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ec'),
#   'RN_INDI': 770773,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 201806,
#   'COD1': 'E11'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ed'),
#   'RN_INDI': 26921,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ee'),
#   'RN_INDI': 51743,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ef'),
#   'RN_INDI': 136900,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f0'),
#   'RN_INDI': 254163,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f1'),
#   'RN_INDI': 513026,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f2'),
#   'RN_INDI': 738834,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f3'),
#   'RN_INDI': 889348,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f4'),
#   'RN_INDI': 165492,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f5'),
#   'RN_INDI': 183863,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f6'),
#   'RN_INDI': 216674,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f7'),
#   'RN_INDI': 326051,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f8'),
#   'RN_INDI': 354997,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561f9'),
#   'RN_INDI': 375650,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561fa'),
#   'RN_INDI': 398604,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561fb'),
#   'RN_INDI': 414026,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561fc'),
#   'RN_INDI': 547878,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561fd'),
#   'RN_INDI': 689623,
#   'BTH_YYYY': 1952,
#   'DTH_YYYYMM': 201110,
#   'COD1': 'J84'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561fe'),
#   'RN_INDI': 733753,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3561ff'),
#   'RN_INDI': 941010,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356200'),
#   'RN_INDI': 4392,
#   'BTH_YYYY': 1953,
#   'DTH_YYYYMM': 201204,
#   'COD1': 'N18'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356201'),
#   'RN_INDI': 91952,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356202'),
#   'RN_INDI': 104229,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356203'),
#   'RN_INDI': 171740,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356204'),
#   'RN_INDI': 317094,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356205'),
#   'RN_INDI': 359683,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356206'),
#   'RN_INDI': 441482,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356207'),
#   'RN_INDI': 474187,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356208'),
#   'RN_INDI': 534288,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356209'),
#   'RN_INDI': 649286,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35620a'),
#   'RN_INDI': 680896,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35620b'),
#   'RN_INDI': 734772,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35620c'),
#   'RN_INDI': 778752,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35620d'),
#   'RN_INDI': 965940,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35620e'),
#   'RN_INDI': 997203,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35620f'),
#   'RN_INDI': 267582,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356210'),
#   'RN_INDI': 366576,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356211'),
#   'RN_INDI': 396281,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356212'),
#   'RN_INDI': 405681,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356213'),
#   'RN_INDI': 632149,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356214'),
#   'RN_INDI': 744818,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356215'),
#   'RN_INDI': 757675,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356216'),
#   'RN_INDI': 1003337,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356217'),
#   'RN_INDI': 111233,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356218'),
#   'RN_INDI': 184935,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356219'),
#   'RN_INDI': 322714,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35621a'),
#   'RN_INDI': 365179,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35621b'),
#   'RN_INDI': 489958,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35621c'),
#   'RN_INDI': 526975,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35621d'),
#   'RN_INDI': 576619,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35621e'),
#   'RN_INDI': 616301,
#   'BTH_YYYY': 1955,
#   'DTH_YYYYMM': 201012,
#   'COD1': 'T66-T78',
#   'COD2': 'X60-X84'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35621f'),
#   'RN_INDI': 691360,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356220'),
#   'RN_INDI': 698203,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356221'),
#   'RN_INDI': 724356,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356222'),
#   'RN_INDI': 767776,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356223'),
#   'RN_INDI': 855875,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356224'),
#   'RN_INDI': 961636,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356225'),
#   'RN_INDI': 47686,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356226'),
#   'RN_INDI': 446544,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356227'),
#   'RN_INDI': 479670,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356228'),
#   'RN_INDI': 511798,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356229'),
#   'RN_INDI': 534381,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35622a'),
#   'RN_INDI': 544817,
#   'BTH_YYYY': 1956,
#   'DTH_YYYYMM': 201912,
#   'COD1': 'C83'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35622b'),
#   'RN_INDI': 593807,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35622c'),
#   'RN_INDI': 658643,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35622d'),
#   'RN_INDI': 712367,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35622e'),
#   'RN_INDI': 758449,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35622f'),
#   'RN_INDI': 759109,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356230'),
#   'RN_INDI': 138777,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356231'),
#   'RN_INDI': 190943,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356232'),
#   'RN_INDI': 217974,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356233'),
#   'RN_INDI': 280296,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356234'),
#   'RN_INDI': 291326,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356235'),
#   'RN_INDI': 326525,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356236'),
#   'RN_INDI': 411755,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356237'),
#   'RN_INDI': 567118,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356238'),
#   'RN_INDI': 573784,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356239'),
#   'RN_INDI': 946035,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35623a'),
#   'RN_INDI': 953845,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35623b'),
#   'RN_INDI': 996319,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35623c'),
#   'RN_INDI': 36941,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35623d'),
#   'RN_INDI': 174428,
#   'BTH_YYYY': 1958,
#   'DTH_YYYYMM': 200709,
#   'COD1': 'F10-F19'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35623e'),
#   'RN_INDI': 201324,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35623f'),
#   'RN_INDI': 312513,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356240'),
#   'RN_INDI': 399523,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356241'),
#   'RN_INDI': 635359,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356242'),
#   'RN_INDI': 721929,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356243'),
#   'RN_INDI': 783723,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356244'),
#   'RN_INDI': 934842,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356245'),
#   'RN_INDI': 956347,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356246'),
#   'RN_INDI': 6907,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356247'),
#   'RN_INDI': 139052,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356248'),
#   'RN_INDI': 150062,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356249'),
#   'RN_INDI': 255665,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35624a'),
#   'RN_INDI': 302152,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35624b'),
#   'RN_INDI': 323839,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35624c'),
#   'RN_INDI': 362517,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35624d'),
#   'RN_INDI': 474121,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35624e'),
#   'RN_INDI': 586351,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35624f'),
#   'RN_INDI': 596632,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356250'),
#   'RN_INDI': 741694,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356251'),
#   'RN_INDI': 753025,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356252'),
#   'RN_INDI': 834250,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356253'),
#   'RN_INDI': 909636,
#   'BTH_YYYY': 1959,
#   'DTH_YYYYMM': 201608,
#   'COD1': 'N17'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356254'),
#   'RN_INDI': 941014,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356255'),
#   'RN_INDI': 28967,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356256'),
#   'RN_INDI': 45383,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356257'),
#   'RN_INDI': 120601,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356258'),
#   'RN_INDI': 142037,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356259'),
#   'RN_INDI': 183094,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35625a'),
#   'RN_INDI': 237870,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35625b'),
#   'RN_INDI': 249100,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35625c'),
#   'RN_INDI': 253557,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35625d'),
#   'RN_INDI': 257985,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35625e'),
#   'RN_INDI': 276428,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35625f'),
#   'RN_INDI': 315899,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356260'),
#   'RN_INDI': 323550,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356261'),
#   'RN_INDI': 350191,
#   'BTH_YYYY': 1960,
#   'DTH_YYYYMM': 202102},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356262'),
#   'RN_INDI': 479772,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356263'),
#   'RN_INDI': 733272,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356264'),
#   'RN_INDI': 764856,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356265'),
#   'RN_INDI': 784523,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356266'),
#   'RN_INDI': 800326,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356267'),
#   'RN_INDI': 848771,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356268'),
#   'RN_INDI': 849697,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356269'),
#   'RN_INDI': 857971,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35626a'),
#   'RN_INDI': 874557,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35626b'),
#   'RN_INDI': 902791,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35626c'),
#   'RN_INDI': 933428,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35626d'),
#   'RN_INDI': 62782,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35626e'),
#   'RN_INDI': 181948,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35626f'),
#   'RN_INDI': 213565,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356270'),
#   'RN_INDI': 272276,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356271'),
#   'RN_INDI': 272384,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356272'),
#   'RN_INDI': 280180,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356273'),
#   'RN_INDI': 417450,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356274'),
#   'RN_INDI': 607228,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356275'),
#   'RN_INDI': 629778,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356276'),
#   'RN_INDI': 643505,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356277'),
#   'RN_INDI': 774338,
#   'BTH_YYYY': 1961,
#   'DTH_YYYYMM': 201711,
#   'COD1': 'F10-F19'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356278'),
#   'RN_INDI': 843214,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356279'),
#   'RN_INDI': 888311,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35627a'),
#   'RN_INDI': 899496,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35627b'),
#   'RN_INDI': 913378,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35627c'),
#   'RN_INDI': 13456,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35627d'),
#   'RN_INDI': 54310,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35627e'),
#   'RN_INDI': 89343,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35627f'),
#   'RN_INDI': 231812,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356280'),
#   'RN_INDI': 244210,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356281'),
#   'RN_INDI': 290156,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356282'),
#   'RN_INDI': 358065,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356283'),
#   'RN_INDI': 417917,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356284'),
#   'RN_INDI': 616341,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356285'),
#   'RN_INDI': 630247,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356286'),
#   'RN_INDI': 727759,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356287'),
#   'RN_INDI': 761432,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356288'),
#   'RN_INDI': 784394,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356289'),
#   'RN_INDI': 786621,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35628a'),
#   'RN_INDI': 798660,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35628b'),
#   'RN_INDI': 950140,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35628c'),
#   'RN_INDI': 8123,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35628d'),
#   'RN_INDI': 64464,
#   'BTH_YYYY': 1963,
#   'DTH_YYYYMM': 201811,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35628e'),
#   'RN_INDI': 171250,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35628f'),
#   'RN_INDI': 197204,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356290'),
#   'RN_INDI': 293850,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356291'),
#   'RN_INDI': 334789,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356292'),
#   'RN_INDI': 507721,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356293'),
#   'RN_INDI': 513398,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356294'),
#   'RN_INDI': 556042,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356295'),
#   'RN_INDI': 699248,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356296'),
#   'RN_INDI': 780676,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356297'),
#   'RN_INDI': 790573,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356298'),
#   'RN_INDI': 806729,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356299'),
#   'RN_INDI': 866221,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35629a'),
#   'RN_INDI': 58754,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35629b'),
#   'RN_INDI': 62197,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35629c'),
#   'RN_INDI': 82185,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35629d'),
#   'RN_INDI': 83610,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35629e'),
#   'RN_INDI': 114351,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35629f'),
#   'RN_INDI': 223544,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a0'),
#   'RN_INDI': 328999,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a1'),
#   'RN_INDI': 332538,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a2'),
#   'RN_INDI': 338796,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a3'),
#   'RN_INDI': 406502,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a4'),
#   'RN_INDI': 557653,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a5'),
#   'RN_INDI': 637891,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a6'),
#   'RN_INDI': 646640,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a7'),
#   'RN_INDI': 777069,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a8'),
#   'RN_INDI': 961315,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562a9'),
#   'RN_INDI': 212874,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562aa'),
#   'RN_INDI': 254322,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ab'),
#   'RN_INDI': 436198,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ac'),
#   'RN_INDI': 444084,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ad'),
#   'RN_INDI': 481258,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ae'),
#   'RN_INDI': 507438,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562af'),
#   'RN_INDI': 529564,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b0'),
#   'RN_INDI': 594837,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b1'),
#   'RN_INDI': 643311,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b2'),
#   'RN_INDI': 649389,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b3'),
#   'RN_INDI': 737330,
#   'BTH_YYYY': 1965,
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C50'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b4'),
#   'RN_INDI': 771454,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b5'),
#   'RN_INDI': 1010728,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b6'),
#   'RN_INDI': 13228,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b7'),
#   'RN_INDI': 93403,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b8'),
#   'RN_INDI': 194296,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562b9'),
#   'RN_INDI': 250810,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ba'),
#   'RN_INDI': 290097,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562bb'),
#   'RN_INDI': 327665,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562bc'),
#   'RN_INDI': 336032,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562bd'),
#   'RN_INDI': 376807,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562be'),
#   'RN_INDI': 388840,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562bf'),
#   'RN_INDI': 393656,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c0'),
#   'RN_INDI': 400003,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c1'),
#   'RN_INDI': 419667,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c2'),
#   'RN_INDI': 565772,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c3'),
#   'RN_INDI': 629788,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c4'),
#   'RN_INDI': 678128,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c5'),
#   'RN_INDI': 683071,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c6'),
#   'RN_INDI': 727629,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c7'),
#   'RN_INDI': 879081,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c8'),
#   'RN_INDI': 967749,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562c9'),
#   'RN_INDI': 60947,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ca'),
#   'RN_INDI': 123392,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562cb'),
#   'RN_INDI': 137557,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562cc'),
#   'RN_INDI': 233697,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562cd'),
#   'RN_INDI': 245082,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ce'),
#   'RN_INDI': 286410,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562cf'),
#   'RN_INDI': 305719,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d0'),
#   'RN_INDI': 440063,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d1'),
#   'RN_INDI': 490275,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d2'),
#   'RN_INDI': 503543,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d3'),
#   'RN_INDI': 506073,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d4'),
#   'RN_INDI': 552401,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d5'),
#   'RN_INDI': 582426,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d6'),
#   'RN_INDI': 622548,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d7'),
#   'RN_INDI': 689166,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d8'),
#   'RN_INDI': 752392,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562d9'),
#   'RN_INDI': 794554,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562da'),
#   'RN_INDI': 817856,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562db'),
#   'RN_INDI': 834908,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562dc'),
#   'RN_INDI': 846679,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562dd'),
#   'RN_INDI': 959064,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562de'),
#   'RN_INDI': 6616,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562df'),
#   'RN_INDI': 17781,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e0'),
#   'RN_INDI': 74642,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e1'),
#   'RN_INDI': 113162,
#   'BTH_YYYY': 1968,
#   'DTH_YYYYMM': 201508,
#   'COD1': 'K70'},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e2'),
#   'RN_INDI': 158220,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e3'),
#   'RN_INDI': 170619,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e4'),
#   'RN_INDI': 187296,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e5'),
#   'RN_INDI': 297639,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e6'),
#   'RN_INDI': 376684,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e7'),
#   'RN_INDI': 414618,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e8'),
#   'RN_INDI': 417458,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562e9'),
#   'RN_INDI': 439422,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ea'),
#   'RN_INDI': 492073,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562eb'),
#   'RN_INDI': 553458,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ec'),
#   'RN_INDI': 554157,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ed'),
#   'RN_INDI': 559413,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ee'),
#   'RN_INDI': 560319,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ef'),
#   'RN_INDI': 565652,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f0'),
#   'RN_INDI': 655520,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f1'),
#   'RN_INDI': 700176,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f2'),
#   'RN_INDI': 745298,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f3'),
#   'RN_INDI': 780304,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f4'),
#   'RN_INDI': 795056,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f5'),
#   'RN_INDI': 815235,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f6'),
#   'RN_INDI': 89809,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f7'),
#   'RN_INDI': 127572,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f8'),
#   'RN_INDI': 163932,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562f9'),
#   'RN_INDI': 176697,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562fa'),
#   'RN_INDI': 213984,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562fb'),
#   'RN_INDI': 241985,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562fc'),
#   'RN_INDI': 285810,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562fd'),
#   'RN_INDI': 313646,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562fe'),
#   'RN_INDI': 328638,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3562ff'),
#   'RN_INDI': 350246,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356300'),
#   'RN_INDI': 442751,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356301'),
#   'RN_INDI': 466008,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356302'),
#   'RN_INDI': 485457,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356303'),
#   'RN_INDI': 505466,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356304'),
#   'RN_INDI': 533519,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356305'),
#   'RN_INDI': 638590,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356306'),
#   'RN_INDI': 646093,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356307'),
#   'RN_INDI': 828266,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356308'),
#   'RN_INDI': 905465,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356309'),
#   'RN_INDI': 933678,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35630a'),
#   'RN_INDI': 1000068,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35630b'),
#   'RN_INDI': 85360,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35630c'),
#   'RN_INDI': 92707,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35630d'),
#   'RN_INDI': 253233,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35630e'),
#   'RN_INDI': 262759,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35630f'),
#   'RN_INDI': 332455,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356310'),
#   'RN_INDI': 481221,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356311'),
#   'RN_INDI': 561326,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356312'),
#   'RN_INDI': 604549,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356313'),
#   'RN_INDI': 639227,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356314'),
#   'RN_INDI': 677413,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356315'),
#   'RN_INDI': 843082,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356316'),
#   'RN_INDI': 905593,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356317'),
#   'RN_INDI': 913018,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356318'),
#   'RN_INDI': 932986,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356319'),
#   'RN_INDI': 8651,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35631a'),
#   'RN_INDI': 14754,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35631b'),
#   'RN_INDI': 53861,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35631c'),
#   'RN_INDI': 62118,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35631d'),
#   'RN_INDI': 172716,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35631e'),
#   'RN_INDI': 182649,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35631f'),
#   'RN_INDI': 241974,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356320'),
#   'RN_INDI': 262509,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356321'),
#   'RN_INDI': 312669,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356322'),
#   'RN_INDI': 315946,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356323'),
#   'RN_INDI': 367659,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356324'),
#   'RN_INDI': 378613,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356325'),
#   'RN_INDI': 413591,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356326'),
#   'RN_INDI': 488703,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356327'),
#   'RN_INDI': 545148,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356328'),
#   'RN_INDI': 607798,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356329'),
#   'RN_INDI': 822808,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35632a'),
#   'RN_INDI': 961069,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35632b'),
#   'RN_INDI': 970269,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35632c'),
#   'RN_INDI': 55619,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35632d'),
#   'RN_INDI': 92721,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35632e'),
#   'RN_INDI': 98010,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35632f'),
#   'RN_INDI': 412233,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356330'),
#   'RN_INDI': 439222,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356331'),
#   'RN_INDI': 449936,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356332'),
#   'RN_INDI': 561313,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356333'),
#   'RN_INDI': 605092,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356334'),
#   'RN_INDI': 665753,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356335'),
#   'RN_INDI': 731675,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356336'),
#   'RN_INDI': 757190,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356337'),
#   'RN_INDI': 826718,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356338'),
#   'RN_INDI': 996207,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356339'),
#   'RN_INDI': 203261,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35633a'),
#   'RN_INDI': 306433,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35633b'),
#   'RN_INDI': 385559,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35633c'),
#   'RN_INDI': 416604,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35633d'),
#   'RN_INDI': 527979,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35633e'),
#   'RN_INDI': 739343,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35633f'),
#   'RN_INDI': 783799,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356340'),
#   'RN_INDI': 828317,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356341'),
#   'RN_INDI': 841175,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356342'),
#   'RN_INDI': 986005,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356343'),
#   'RN_INDI': 1004971,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356344'),
#   'RN_INDI': 51105,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356345'),
#   'RN_INDI': 176242,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356346'),
#   'RN_INDI': 203402,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356347'),
#   'RN_INDI': 349647,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356348'),
#   'RN_INDI': 420854,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356349'),
#   'RN_INDI': 423842,
#   'BTH_YYYY': 1974},
# ...
#   'RN_INDI': 971748,
#   'BTH_YYYY': 1997},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356485'),
#   'RN_INDI': 225503,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356486'),
#   'RN_INDI': 269902,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356487'),
#   'RN_INDI': 302781,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356488'),
#   'RN_INDI': 326883,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356489'),
#   'RN_INDI': 335411,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35648a'),
#   'RN_INDI': 468958,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35648b'),
#   'RN_INDI': 539874,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35648c'),
#   'RN_INDI': 695844,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35648d'),
#   'RN_INDI': 787867,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35648e'),
#   'RN_INDI': 806727,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35648f'),
#   'RN_INDI': 905339,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356490'),
#   'RN_INDI': 916359,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356491'),
#   'RN_INDI': 951174,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356492'),
#   'RN_INDI': 73610,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356493'),
#   'RN_INDI': 163969,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356494'),
#   'RN_INDI': 179020,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356495'),
#   'RN_INDI': 238712,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356496'),
#   'RN_INDI': 308173,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356497'),
#   'RN_INDI': 310621,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356498'),
#   'RN_INDI': 425871,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356499'),
#   'RN_INDI': 486937,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35649a'),
#   'RN_INDI': 563494,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35649b'),
#   'RN_INDI': 760126,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35649c'),
#   'RN_INDI': 879593,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35649d'),
#   'RN_INDI': 82310,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35649e'),
#   'RN_INDI': 84893,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35649f'),
#   'RN_INDI': 161487,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a0'),
#   'RN_INDI': 176406,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a1'),
#   'RN_INDI': 257664,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a2'),
#   'RN_INDI': 466981,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a3'),
#   'RN_INDI': 577639,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a4'),
#   'RN_INDI': 708939,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a5'),
#   'RN_INDI': 753723,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a6'),
#   'RN_INDI': 813440,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a7'),
#   'RN_INDI': 941612,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a8'),
#   'RN_INDI': 950411,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564a9'),
#   'RN_INDI': 20218,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564aa'),
#   'RN_INDI': 49262,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ab'),
#   'RN_INDI': 134908,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ac'),
#   'RN_INDI': 158558,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ad'),
#   'RN_INDI': 208900,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ae'),
#   'RN_INDI': 250136,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564af'),
#   'RN_INDI': 263640,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b0'),
#   'RN_INDI': 273079,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b1'),
#   'RN_INDI': 396613,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b2'),
#   'RN_INDI': 413012,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b3'),
#   'RN_INDI': 519015,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b4'),
#   'RN_INDI': 546675,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b5'),
#   'RN_INDI': 561648,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b6'),
#   'RN_INDI': 864522,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b7'),
#   'RN_INDI': 870877,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b8'),
#   'RN_INDI': 899365,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564b9'),
#   'RN_INDI': 3085,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ba'),
#   'RN_INDI': 299738,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564bb'),
#   'RN_INDI': 364349,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564bc'),
#   'RN_INDI': 404279,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564bd'),
#   'RN_INDI': 716015,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564be'),
#   'RN_INDI': 802803,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564bf'),
#   'RN_INDI': 938422,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c0'),
#   'RN_INDI': 5835,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c1'),
#   'RN_INDI': 18010,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c2'),
#   'RN_INDI': 92285,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c3'),
#   'RN_INDI': 161387,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c4'),
#   'RN_INDI': 170806,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c5'),
#   'RN_INDI': 221998,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c6'),
#   'RN_INDI': 314923,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c7'),
#   'RN_INDI': 601775,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c8'),
#   'RN_INDI': 631006,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564c9'),
#   'RN_INDI': 636187,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ca'),
#   'RN_INDI': 863171,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564cb'),
#   'RN_INDI': 963693,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564cc'),
#   'RN_INDI': 28170,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564cd'),
#   'RN_INDI': 325390,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ce'),
#   'RN_INDI': 440692,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564cf'),
#   'RN_INDI': 645066,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d0'),
#   'RN_INDI': 744544,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d1'),
#   'RN_INDI': 759439,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d2'),
#   'RN_INDI': 772460,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d3'),
#   'RN_INDI': 973079,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d4'),
#   'RN_INDI': 151244,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d5'),
#   'RN_INDI': 248794,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d6'),
#   'RN_INDI': 300615,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d7'),
#   'RN_INDI': 314882,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d8'),
#   'RN_INDI': 398665,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564d9'),
#   'RN_INDI': 407118,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564da'),
#   'RN_INDI': 658189,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564db'),
#   'RN_INDI': 658751,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564dc'),
#   'RN_INDI': 758751,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564dd'),
#   'RN_INDI': 847505,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564de'),
#   'RN_INDI': 911175,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564df'),
#   'RN_INDI': 2086938,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e0'),
#   'RN_INDI': 2086947,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e1'),
#   'RN_INDI': 2086957,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e2'),
#   'RN_INDI': 2087001,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e3'),
#   'RN_INDI': 2087359,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e4'),
#   'RN_INDI': 2088391,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e5'),
#   'RN_INDI': 2088649,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e6'),
#   'RN_INDI': 2089304,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e7'),
#   'RN_INDI': 2089654,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e8'),
#   'RN_INDI': 2089788,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564e9'),
#   'RN_INDI': 2092954,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ea'),
#   'RN_INDI': 2000020,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564eb'),
#   'RN_INDI': 2010719,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ec'),
#   'RN_INDI': 2018681,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ed'),
#   'RN_INDI': 2018912,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ee'),
#   'RN_INDI': 2020810,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ef'),
#   'RN_INDI': 2026212,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f0'),
#   'RN_INDI': 2042563,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f1'),
#   'RN_INDI': 2042976,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f2'),
#   'RN_INDI': 2072334,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f3'),
#   'RN_INDI': 2077234,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f4'),
#   'RN_INDI': 2078627,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f5'),
#   'RN_INDI': 2083536,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f6'),
#   'RN_INDI': 2029345,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f7'),
#   'RN_INDI': 2032575,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f8'),
#   'RN_INDI': 2035362,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564f9'),
#   'RN_INDI': 2040013,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564fa'),
#   'RN_INDI': 2061761,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564fb'),
#   'RN_INDI': 2071250,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564fc'),
#   'RN_INDI': 2084440,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564fd'),
#   'RN_INDI': 2018134,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564fe'),
#   'RN_INDI': 2023673,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a3564ff'),
#   'RN_INDI': 2038651,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356500'),
#   'RN_INDI': 2040254,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356501'),
#   'RN_INDI': 2058808,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356502'),
#   'RN_INDI': 2061873,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356503'),
#   'RN_INDI': 2064588,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356504'),
#   'RN_INDI': 2080462,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356505'),
#   'RN_INDI': 2080886,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356506'),
#   'RN_INDI': 2003497,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356507'),
#   'RN_INDI': 2007534,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356508'),
#   'RN_INDI': 2013766,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356509'),
#   'RN_INDI': 2022479,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35650a'),
#   'RN_INDI': 2043266,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35650b'),
#   'RN_INDI': 2070235,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35650c'),
#   'RN_INDI': 2075679,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35650d'),
#   'RN_INDI': 2011515,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35650e'),
#   'RN_INDI': 2026146,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35650f'),
#   'RN_INDI': 2048842,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356510'),
#   'RN_INDI': 2052260,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356511'),
#   'RN_INDI': 2058256,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356512'),
#   'RN_INDI': 2060095,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356513'),
#   'RN_INDI': 2061241,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356514'),
#   'RN_INDI': 2019267,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356515'),
#   'RN_INDI': 2024260,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356516'),
#   'RN_INDI': 2029436,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356517'),
#   'RN_INDI': 2042518,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356518'),
#   'RN_INDI': 2045636,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356519'),
#   'RN_INDI': 2062864,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35651a'),
#   'RN_INDI': 2066728,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35651b'),
#   'RN_INDI': 2078794,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35651c'),
#   'RN_INDI': 3000357,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35651d'),
#   'RN_INDI': 2000846,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35651e'),
#   'RN_INDI': 2004812,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35651f'),
#   'RN_INDI': 2007337,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356520'),
#   'RN_INDI': 2018770,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356521'),
#   'RN_INDI': 2020718,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356522'),
#   'RN_INDI': 2037391,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356523'),
#   'RN_INDI': 2037727,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356524'),
#   'RN_INDI': 2062330,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356525'),
#   'RN_INDI': 2073308,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356526'),
#   'RN_INDI': 2074479,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356527'),
#   'RN_INDI': 2002123,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356528'),
#   'RN_INDI': 2002417,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356529'),
#   'RN_INDI': 2041982,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35652a'),
#   'RN_INDI': 2044310,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35652b'),
#   'RN_INDI': 2063620,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35652c'),
#   'RN_INDI': 2070327,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35652d'),
#   'RN_INDI': 2080025,
#   'BTH_YYYY': 2014,
#   'DTH_YYYYMM': 202004},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35652e'),
#   'RN_INDI': 2084429,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a35652f'),
#   'RN_INDI': 2037151,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356530'),
#   'RN_INDI': 2040322,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356531'),
#   'RN_INDI': 2048579,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356532'),
#   'RN_INDI': 2057743,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356533'),
#   'RN_INDI': 2063541,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356534'),
#   'RN_INDI': 2070251,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356535'),
#   'RN_INDI': 2077125,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd1a45d6ce1f3a356536'),
#   'RN_INDI': 3000758,
#   'BTH_YYYY': 2015}]

# %%
df_BND = pd.DataFrame(list_BND)

# %%
df_BND
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_BND.to_csv('./NSC2_BND.csv')
